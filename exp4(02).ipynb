# %% [markdown]
# <a href="https://colab.research.google.com/github/mdrehantabish123/mdrehantabish123-Data_Science_Lab_SE_A_38/blob/main/exp4(02).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Create a sample dataset
data = np.array([12, 15, 18, 20, 22, 25, 30, 32, 35, 40])

# Compute the mean
mean_value = np.mean(data)

# Compute the median
median_value = np.median(data)

# Compute the variance
variance_value = np.var(data)

# Compute the standard deviation
std_dev_value = np.std(data)

print(f"Dataset: {data}")
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Variance: {variance_value}")
print(f"Standard Deviation: {std_dev_value}")
# Out:
# Dataset: [12 15 18 20 22 25 30 32 35 40]
# Mean: 24.9
# Median: 23.5
# Variance: 75.09
# Standard Deviation: 8.665448632355973
