# %% [markdown]
# <a href="https://colab.research.google.com/github/mdrehantabish123/mdrehantabish123-Data_Science_Lab_SE_A_38/blob/main/practical_4(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Create a sample dataset
data = np.array([12, 15, 18, 20, 22, 25, 28, 30, 32, 35, 40, 45, 50])

# Compute the mean
mean_value = np.mean(data)

# Compute the median
median_value = np.median(data)

# Compute the variance
variance_value = np.var(data)

# Compute the standard deviation
std_dev_value = np.std(data)

print(f"Dataset: {data}")
print(f"Mean: {mean_value}")
print(f"Median: {median_value}")
print(f"Variance: {variance_value}")
print(f"Standard Deviation: {std_dev_value}")
# Out:
# Dataset: [12 15 18 20 22 25 28 30 32 35 40 45 50]
# Mean: 28.615384615384617
# Median: 28.0
# Variance: 124.23668639053254
# Standard Deviation: 11.14615119180305
